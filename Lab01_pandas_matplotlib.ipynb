# %%
#import modules
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_data = pd.read_csv("Data_for_Transformation.csv")
lpt.scatter(main_data["Age"],main_data["Salary"])
plt.xlabel("Age")
plt.ylable("Salary")
plt.show()

# %%
plt.hist(main_data["Salary"],
         bins = 10, color = "yellow")
plt.xlable("Salaries")
plt.show()

# %%
fig_size = plt.figure(figsize=(8,6))
plt.bar(main_data["Country"],main_data["Salary"], color="green")
plt.xlabel("Salaries")
plt.ylabel("Countries")
plt.title("Bar chart of country vs salary")
plt.show()
