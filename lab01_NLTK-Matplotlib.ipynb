# %%
import nltk
import matplotlib.pyplot as plt
import pandas as pd

# %%
my_text = "#github was down for approx a amin, who noticed th is??"

import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

remove_link = re.sub(r'https?:\/\/.*[\r\n]*','',my_text)
remove_link = re.sub(r'#','',remove_link)
print(remove_link)
# Out:
# github was down for approx a amin, who noticed th is??

# %%
from nltk.tokenize import sent_tokenize
text="Daniel James leaves united for 25m. Only Cristiano Ronaldo, Romelu Lukaku and Angel di Maria have left the club for higher fees #mufc"
nltk.download("punkt")
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['Daniel James leaves united for 25m.', 'Only Cristiano Ronaldo, Romelu Lukaku and Angel di Maria have left the club for higher fees #mufc']

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']

# %%
#frequency distribution
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
fdist.most_common(4)
import matplotlib.pyplot as plt
fdist.plot(30, cumulative = False, color = "green")
plt.show()

# %%
#stop words
from nltk.corpus import stopwords
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'up', 'how', "it's", "needn't", 'because', 'most', "weren't", 'ain', 've', 'about', 'ourselves', 'there', 'will', 'an', 'such', 'we', 'you', 'too', 'doesn', 'of', 'can', 'ours', 'the', 'has', "mightn't", 'your', "isn't", "shouldn't", 'why', "wouldn't", 'this', 'be', 'while', 'on', 'yourselves', 'where', 'ma', 'was', 'her', 'won', "mustn't", 'until', 'being', 'down', 'all', 'hadn', 'not', 'y', 'here', 'few', "won't", 'he', 'those', 'am', 'own', 'are', "haven't", 'do', 'both', 'our', 'she', 'been', 'my', 'does', 'd', 'only', 'against', 'mightn', 'them', 'through', 'they', 'wasn', 'isn', 'to', 'after', 'what', 'again', "that'll", 'herself', 're', 'yourself', 'don', 'more', 'o', 'll', 'myself', 's', "hadn't", 'any', 'these', 'nor', 'then', 'hers', 'him', 'that', "shan't", 'having', 'should', 'and', 'a', 'shouldn', "wasn't", "you've", 'me', 'with', 'very', 'some', 'yours', 'now', 'hasn', 'out', 'were', 'than', 'so', 'over', 'just', 'needn', 'mustn', 'off', "don't", 'doing', 'who', 'from', 't', 'wouldn', 'i', 'when', 'in', 'itself', 'couldn', 'himself', 'it', "aren't", 'between', 'by', 'once', 'if', 'same', 'themselves', 'into', "couldn't", 'shan', 'at', 'above', 'as', 'their', "you'll", 'during', 'which', 'had', 'before', "doesn't", 'or', 'is', 'no', "hasn't", "didn't", 'weren', 'his', 'did', 'theirs', 'further', 'other', 'below', "should've", 'each', 'didn', 'haven', 'whom', 'm', 'but', 'for', 'under', 'aren', 'have', "you're", "she's", 'its', "you'd"}

# %%
filtered_sent=[]
for w in tokenized_word:
  if w not in stop_words:
    filtered_sent.append(w)
    print("Tokenized Sentence:", tokenized_word)
    print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'Angel']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'Angel', 'di']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'Angel', 'di', 'Maria']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'Angel', 'di', 'Maria', 'left']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'Angel', 'di', 'Maria', 'left', 'club']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'Angel', 'di', 'Maria', 'left', 'club', 'higher']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'Angel', 'di', 'Maria', 'left', 'club', 'higher', 'fees']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'Angel', 'di', 'Maria', 'left', 'club', 'higher', 'fees', '#']
# Tokenized Sentence: ['Daniel', 'James', 'leaves', 'united', 'for', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'and', 'Angel', 'di', 'Maria', 'have', 'left', 'the', 'club', 'for', 'higher', 'fees', '#', 'mufc']
# Filterd Sentence: ['Daniel', 'James', 'leaves', 'united', '25m', '.', 'Only', 'Cristiano', 'Ronaldo', ',', 'Romelu', 'Lukaku', 'Angel', 'di', 'Maria', 'left', 'club', 'higher', 'fees', '#', 'mufc']

# %%
#stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_word=[]
for w in filtered_sent:
   stemmed_words.append(ps.stem(w))

print("filtered Sentence:", filtered_sent)
print("Stemmed Sentence:", stemmed_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-688e0f820aa2> in <module>()
#       7 stemmed_word=[]
#       8 for w in filtered_sent:
# ----> 9    stemmed_words.append(ps.stem(w))
#      10
#      11 print("filtered Sentence:", filtered_sent)
#
# NameError: name 'stemmed_words' is not defined

# %%
#Lexicon Normalization
#performing stemming and lemmatization

from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')
lem = WordNetLemmatizer()

from nltk.stem.porter import porterLemmatizer()

word = "Crying"
print("Lemmatized Word:",len.Lemmatize(word,"v"))
print("Stemmed Word:",stem.stem(word))
# Out:
#   File "<ipython-input-17-2de0c8332dd0>", line 8
#     from nltk.stem.porter import porterLemmatizer()
#                                                  ^
# SyntaxError: invalid syntax
